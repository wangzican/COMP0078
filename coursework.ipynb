# %%
import Q1 as F

# %%
F.plot_graph()
# Out:
# Q1 (a):
# Q1 (b):
# k = 1:  [2.5]
# k = 2:  [1.5 0.4]
# k = 3:  [ 9.  -7.1  1.5]
# k = 4:  [-5.         15.16666667 -8.5         1.33333333]
#
#
# Q1 (c):
# k = 1:  3.25
# k = 2:  3.05
# k = 3:  0.8000000000000008
# k = 4:  1.8469202985258544e-23

# %%
F.draw_sin_with_noise()
# Out:
# Q2 (a) i:

# %%
F.fitting_sin()
# Out:
# Q2 (a) ii:

# %%
F.sin_ln_mse()
# Out:
# Q2 (b):

# %%
F.thousand_points()
# Out:
# Q2 (c):

# %%
F.hundred_iter()
# Out:
# Iteration  0
# Iteration  1
# Iteration  2
# Iteration  3
# Iteration  4
# Iteration  5
# Iteration  6
# Iteration  7
# Iteration  8
# Iteration  9
# Iteration  10
# Iteration  11
# Iteration  12
# Iteration  13
# Iteration  14
# Iteration  15
# Iteration  16
# Iteration  17
# Iteration  18
# Iteration  19
# Iteration  20
# Iteration  21
# Iteration  22
# Iteration  23
# Iteration  24
# Iteration  25
# Iteration  26
# Iteration  27
# Iteration  28
# Iteration  29
# Iteration  30
# Iteration  31
# Iteration  32
# Iteration  33
# Iteration  34
# Iteration  35
# Iteration  36
# Iteration  37
# Iteration  38
# Iteration  39
# Iteration  40
# Iteration  41
# Iteration  42
# Iteration  43
# Iteration  44
# Iteration  45
# Iteration  46
# Iteration  47
# Iteration  48
# Iteration  49
# Iteration  50
# Iteration  51
# Iteration  52
# Iteration  53
# Iteration  54
# Iteration  55
# Iteration  56
# Iteration  57
# Iteration  58
# Iteration  59
# Iteration  60
# Iteration  61
# Iteration  62
# ...

# %%
F.sin_basis()
# Out:
# Q3 (b):
# Q3 (c):
# Iteration  0
# Iteration  1
# Iteration  2
# Iteration  3
# Iteration  4
# Iteration  5
# Iteration  6
# Iteration  7
# Iteration  8
# Iteration  9
# Iteration  10
# Iteration  11
# Iteration  12
# Iteration  13
# Iteration  14
# Iteration  15
# Iteration  16
# Iteration  17
# Iteration  18
# Iteration  19
# Iteration  20
# Iteration  21
# Iteration  22
# Iteration  23
# Iteration  24
# Iteration  25
# Iteration  26
# Iteration  27
# Iteration  28
# Iteration  29
# Iteration  30
# Iteration  31
# Iteration  32
# Iteration  33
# Iteration  34
# Iteration  35
# Iteration  36
# Iteration  37
# Iteration  38
# Iteration  39
# Iteration  40
# Iteration  41
# Iteration  42
# Iteration  43
# Iteration  44
# Iteration  45
# Iteration  46
# Iteration  47
# Iteration  48
# Iteration  49
# Iteration  50
# Iteration  51
# Iteration  52
# Iteration  53
# Iteration  54
# Iteration  55
# Iteration  56
# Iteration  57
# Iteration  58
# Iteration  59
# Iteration  60
# ...

# %%
F.naive_regression()
# Out:
# Q4, (a):
# training loss is:  [85.86548182]
# testing loss is:  [84.20013806]
# Q4, (b): w is the mean of the training y values.

# %%
F.single_attribute()
# Out:
# Q4, (c):
# for attribute  CRIM
# training loss is:  [71.13515846]
# testing loss is:  [74.20141623]
# for attribute   ZN
# training loss is:  [144.00843377]
# testing loss is:  [148.76462949]
# for attribute  INDUS
# training loss is:  [210.37931037]
# testing loss is:  [213.4978194]
# for attribute  CHAS
# training loss is:  [293.71389184]
# testing loss is:  [295.96760844]
# for attribute  NOX
# training loss is:  [366.51186663]
# testing loss is:  [363.93996745]
# for attribute  RM
# training loss is:  [406.22372593]
# testing loss is:  [410.19818519]
# for attribute  AGE
# training loss is:  [475.05074986]
# testing loss is:  [485.02895973]
# for attribute  DIS
# training loss is:  [556.64927195]
# testing loss is:  [563.64754956]
# for attribute  RAD
# training loss is:  [626.65969883]
# testing loss is:  [637.66105196]
# for attribute  TAX
# training loss is:  [690.21400474]
# testing loss is:  [705.50748852]
# for attribute  PTRATIO
# training loss is:  [752.90893051]
# ...

# %%
F.all_attributes()
# Out:
# Q4, (d):
# training loss is:  [20.96512093]
# testing loss is:  [26.01042815]
