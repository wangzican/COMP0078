# %%
import Q1 as F

# %%
F.plot_graph()
# Out:
# Q1 (a):
# Q1 (b):
# k = 1:  [2.5]
# k = 2:  [1.5 0.4]
# k = 3:  [ 9.  -7.1  1.5]
# k = 4:  [-5.         15.16666667 -8.5         1.33333333]
#
#
# Q1 (c):
# k = 1:  3.25
# k = 2:  3.0499999999999994
# k = 3:  0.7999999999999997
# k = 4:  1.5720628427827108e-23

# %%
F.draw_sin_with_noise()
# Out:
# Q2 (a) i:

# %%
F.fitting_sin()
# Out:
# Q2 (a) ii:

# %%
F.sin_ln_mse()
# Out:
# Q2 (b):

# %%
F.thousand_points()
# Out:
# Q2 (c):

# %%
F.hundred_iter()
# Out:
# Q2 (d):

# %%
F.sin_basis()
# Out:
# Q3 (b):
# Q3 (c):
# Q3 (d):

# %%
_ = F.naive_regression()
# Out:
# Q4, (a):
# training loss is:  82.63040610553938
# testing loss is:  88.37098009009563
# Q4, (b): w is the mean of the training y values.

# %%
_ = F.single_attribute()
# Out:
# Q4, (c):
# for attribute  CRIM
# training loss is:  71.31195567294164
# testing loss is:  73.32645369869375
# for attribute   ZN
# training loss is:  73.69557054501469
# testing loss is:  73.50451901715164
# for attribute  INDUS
# training loss is:  64.44523627972536
# testing loss is:  65.54908240313526
# for attribute  CHAS
# training loss is:  80.45000811683032
# testing loss is:  85.50911194210285
# for attribute  NOX
# training loss is:  70.2176735683381
# testing loss is:  66.93098148613527
# for attribute  RM
# training loss is:  43.56802857506266
# testing loss is:  44.06377448086185
# for attribute  AGE
# training loss is:  73.12109649729385
# testing loss is:  71.52040156580276
# for attribute  DIS
# training loss is:  77.63369659811968
# testing loss is:  82.77652565229053
# for attribute  RAD
# training loss is:  74.06923203778874
# testing loss is:  68.74665089988902
# for attribute  TAX
# training loss is:  65.29248230034554
# testing loss is:  67.46202836287009
# ...

# %%
_ = F.all_attributes()
# Out:
# Q4, (d):
# training loss is:  21.74368589673437
# testing loss is:  25.22426421075927

# %%
_ = F.five_fold()
# Out:
# Q5, (a)
# gamma:  9.094947017729282e-13
# sigma:  128.0
# mean mse:  [1271.08492458]
# gamma:  9.094947017729282e-13
# sigma:  181.01933598375618
# mean mse:  [381.60569958]
# gamma:  9.094947017729282e-13
# sigma:  256.0
# mean mse:  [181.98036232]
# gamma:  9.094947017729282e-13
# sigma:  362.03867196751236
# mean mse:  [47.36966624]
# gamma:  9.094947017729282e-13
# sigma:  512.0
# mean mse:  [23.92125668]
# gamma:  9.094947017729282e-13
# sigma:  724.0773439350247
# mean mse:  [17.14451509]
# gamma:  9.094947017729282e-13
# sigma:  1024.0
# mean mse:  [12.93117011]
# gamma:  9.094947017729282e-13
# sigma:  1448.1546878700494
# mean mse:  [12.35703096]
# gamma:  9.094947017729282e-13
# sigma:  2048.0
# mean mse:  [12.49520682]
# gamma:  9.094947017729282e-13
# sigma:  2896.309375740099
# mean mse:  [12.12869508]
# gamma:  9.094947017729282e-13
# sigma:  4096.0
# mean mse:  [12.09417864]
# gamma:  9.094947017729282e-13
# sigma:  5792.618751480198
# mean mse:  [12.52597857]
# ...

# %%
F.comparing_mse()
# Out:
# Q5, (d)
#
# naive regression:
# train:  83.78985234527026  +-  6.26247889796318
# test:  85.78947664530091  +=  12.509452018137953
#
# for attribute  1 :
# train:  70.47709509112158  +-  5.498721626001413
# test:  76.61820409491654  +=  13.405214146527467
#
# for attribute  2 :
# train:  72.01805902045449  +-  4.35380666009979
# test:  76.94555079883625  +=  9.03303812904632
#
# for attribute  3 :
# train:  66.28915278388905  +-  4.019070996806905
# test:  61.889877785390865  +=  7.918932602611311
#
# for attribute  4 :
# train:  82.77874606411089  +-  3.423033374332823
# test:  81.09520203381527  +=  6.455568965458388
#
# for attribute  5 :
# train:  69.3381932410285  +-  3.943956208288397
# test:  68.55946347943234  +=  7.826373130811961
#
# for attribute  6 :
# train:  43.534255330556036  +-  3.9440371226418565
# test:  44.23686173569679  +=  7.7785510490994065
#
# for attribute  7 :
# train:  71.8320401152542  +-  5.820297123949399
# ...
