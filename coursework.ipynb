# %%
import Q1
# Out:
# k =  1 :  [[2.5]]
# k =  2 :  [[1.5]
#  [0.4]]
# k =  3 :  [[ 9. ]
#  [-7.1]
#  [ 1.5]]
# k =  4 :  [[-5.        ]
#  [15.16666667]
#  [-8.5       ]
#  [ 1.33333333]]
# 3.25
# 3.05
# 0.8000000000000008
# 1.8469202985258544e-23
