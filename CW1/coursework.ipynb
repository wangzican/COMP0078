# %%
import Q1 as F

# %%
F.plot_graph()
# Out:
# Q1 (a):
# Q1 (b):
# k = 1:  [2.5]
# k = 2:  [1.5 0.4]
# k = 3:  [ 9.  -7.1  1.5]
# k = 4:  [-5.         15.16666667 -8.5         1.33333333]
#
#
# Q1 (c):
# k = 1:  3.25
# k = 2:  3.05
# k = 3:  0.8000000000000005
# k = 4:  9.140312168166774e-23

# %%
F.draw_sin_with_noise()
# Out:
# Q2 (a) i:

# %%
F.fitting_sin()
# Out:
# Q2 (a) ii:

# %%
F.sin_ln_mse()
# Out:
# Q2 (b):

# %%
F.thousand_points()
# Out:
# Q2 (c):

# %%
F.hundred_iter()
# Out:
# Q2 (d):

# %%
F.sin_basis()
# Out:
# Q3 (b):
# Q3 (c):
# Q3 (d):

# %%
_ = F.naive_regression()
# Out:
# Q4, (a):
# training loss is:  84.94198564749183
# testing loss is:  83.570701954566
# Q4, (b): w is the mean of the training y values.

# %%
_ = F.single_attribute()
# Out:
# Q4, (c):
# for attribute  CRIM
# training loss is:  71.97751385000994
# testing loss is:  72.13670872619993
# for attribute   ZN
# training loss is:  73.04425048783145
# testing loss is:  74.59676417615762
# for attribute  INDUS
# training loss is:  63.10684241610579
# testing loss is:  67.98582162320423
# for attribute  CHAS
# training loss is:  81.0403910095319
# testing loss is:  84.01665540468431
# for attribute  NOX
# training loss is:  69.50010860567173
# testing loss is:  68.27521161318707
# for attribute  RM
# training loss is:  43.91440437423598
# testing loss is:  43.26660553193888
# for attribute  AGE
# training loss is:  71.25125657997998
# testing loss is:  75.19526539928829
# for attribute  DIS
# training loss is:  79.33647707875176
# testing loss is:  79.29735208611312
# for attribute  RAD
# training loss is:  72.89887464972392
# testing loss is:  71.16334592741082
# for attribute  TAX
# training loss is:  64.1103547097295
# testing loss is:  69.74184835960493
# ...

# %%
_ = F.all_attributes()
# Out:
# Q4, (d):
# training loss is:  22.5498492465754
# testing loss is:  23.61574050433311

# %%
_ = F.five_fold()
# Out:
# Q5, (a)
# gamma:  9.094947017729282e-13
# sigma:  128.0
# mean mse:  [1413.33464262]
# gamma:  9.094947017729282e-13
# sigma:  181.01933598375618
# mean mse:  [520.59274926]
# gamma:  9.094947017729282e-13
# sigma:  256.0
# mean mse:  [257.7949221]
# gamma:  9.094947017729282e-13
# sigma:  362.03867196751236
# mean mse:  [65.90387862]
# gamma:  9.094947017729282e-13
# sigma:  512.0
# mean mse:  [29.5653571]
# gamma:  9.094947017729282e-13
# sigma:  724.0773439350247
# mean mse:  [24.79790065]
# gamma:  9.094947017729282e-13
# sigma:  1024.0
# mean mse:  [19.55600523]
# gamma:  9.094947017729282e-13
# sigma:  1448.1546878700494
# mean mse:  [16.18698405]
# gamma:  9.094947017729282e-13
# sigma:  2048.0
# mean mse:  [15.89561801]
# gamma:  9.094947017729282e-13
# sigma:  2896.309375740099
# mean mse:  [16.22433253]
# gamma:  9.094947017729282e-13
# sigma:  4096.0
# mean mse:  [16.29363298]
# gamma:  9.094947017729282e-13
# sigma:  5792.618751480198
# mean mse:  [16.14268033]
# ...

# %%
F.comparing_mse()
# Out:
# Q5, (d)
#
# naive regression:
# train:  85.36596876788562  +-  3.8995838125490234
# test:  82.87788920272173  +=  7.678324637109068
#
# for attribute  1 :
# train:  71.61756068956745  +-  4.005397668561692
# test:  72.53597064057291  +=  8.009289388493897
#
# for attribute  2 :
# train:  74.24556577382852  +-  3.9231153550417073
# test:  72.30806706107785  +=  7.883563977636998
#
# for attribute  3 :
# train:  66.24382509962916  +-  4.522178783515742
# test:  62.071034457555456  +=  9.036146037035621
#
# for attribute  4 :
# train:  81.35344755031068  +-  5.628202464446032
# test:  83.42393846363538  +=  11.059130991157891
#
# for attribute  5 :
# train:  69.428343089412  +-  4.741885186939082
# test:  68.54502813517757  +=  9.480027708191967
#
# for attribute  6 :
# train:  43.31550432758438  +-  2.722081454028916
# test:  44.52412895524749  +=  5.557703151153281
#
# for attribute  7 :
# train:  72.569985652021  +-  6.075305789999963
# ...

# %%
F.knn_visualize()
# Out:
# Q6:

# %%
F.knn_general_err()
# Out:
# Q7 (a):
# k =  1
# loss =  0.20276000000000002
# k =  2
# loss =  0.20782000000000006
# k =  3
# loss =  0.15597999999999998
# k =  4
# loss =  0.1631
# k =  5
# loss =  0.14943000000000006
# k =  6
# loss =  0.14966999999999997
# k =  7
# loss =  0.14499000000000004
# k =  8
# loss =  0.14536
# k =  9
# loss =  0.14604
# k =  10
# loss =  0.14826000000000006
# k =  11
# loss =  0.14768999999999996
# k =  12
# loss =  0.1490999999999999
# k =  13
# loss =  0.14756000000000002
# k =  14
# loss =  0.14972999999999997
# k =  15
# loss =  0.14804999999999993
# k =  16
# loss =  0.15337999999999996
# k =  17
# loss =  0.14884999999999998
# k =  18
# loss =  0.15149999999999997
# k =  19
# loss =  0.14914
# k =  20
# loss =  0.15106999999999998
# k =  21
# loss =  0.15242
# k =  22
# loss =  0.15472999999999998
# k =  23
# loss =  0.15186999999999998
# k =  24
# loss =  0.1553399999999999
# k =  25
# loss =  0.15546
# k =  26
# loss =  0.15201000000000003
# k =  27
# ...

# %%
F.knn_optimal_k()
# Out:
# Q8 (a):
# m:  100
# best k:  7.242424242424242
# m:  500
# best k:  10.444444444444445
# m:  1000
# best k:  11.909090909090908
# m:  1500
# best k:  14.02020202020202
# m:  2000
# best k:  15.030303030303031
# m:  2500
# best k:  14.252525252525253
# m:  3000
# best k:  16.272727272727273
# m:  3500
# best k:  17.505050505050505
# m:  4000
# best k:  13.919191919191919
